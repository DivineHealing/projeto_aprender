# %% [markdown]
# <h3>Matrizes</h3>

# %% [markdown]
# <b>Até aqui aprendemos a manipular apenas listas (arrays) simples:</b>
#
# + Estrutura de dados unidimensional;
# + Controlada através de um <b>unico indice</b>
#
# <b>Consegue imaginar as situações em que é necessário mais de um índice?</b>
#
# + Tabelas, gráficos 3D, aplicações contábeis, processamento de imagens e visão computacional, jogos, aplicações científicas, projetos de engenharia e etc. <BR>
#
# Considere a tabela a seguir: <BR>
#
#
# <table>
#   <tr>
#     <th>Produto</th>
#     <th>Ano 2010</th>
#     <th>Ano 2011</th>
#     <th>Ano 2012</th>
#   </tr>
#   <tr>
#     <td>Arroz</td>
#     <td>6,00</td>
#     <td>6,50</td>
#     <td>7,00</td>
#   </tr>
#   <tr>
#     <td>Feijão</td>
#     <td>4,00</td>
#     <td>4,35</td>
#     <td>5,25</td>
#   </tr>
#   <tr>
#     <td>Macarrão</td>
#     <td>3,50</td>
#     <td>3,30</td>
#     <td>3,75</td>
#   </tr>
# </table>
#
#
# As aplicações com tabelas são inerentemente maticiais <br>
# + Solução: <b>Matrizes</b>
# + em Python: <b>"Listas de listas"</b>
#
#
#
# <h5>Definição</h5>
# Matrizes são estruturas de dados multidimensionais que necessitam de mais de um índice para serem manipuladas. <br>
#
# São parecidas com listas
# + Semelhanças: Os elementos de uma matriz são referenciados por um mesmo nome;
# + Diferença: Possuem dois ou mais índices;
# + <b>Bidimensionais:</b> Um índice para linhas e outro índice para colunas;
# + Multidimensionais: Podem possuir 2, 3, n índices;
#
# <h5>Definição Matemática</h5>
# Uma <b>matriz</b> é um arranjo tabular de <b style="color:Blue;">M</b><b>x</b><b style="color:Green;">N</b> valores, onde <b style="color:Blue;">M</b> é o numero de <b style="color:Blue;">Linhas</b> e <b style="color:Green;">N</b> é o numero de <b style="color:Green;">colunas</b>.<br>
#
# Os elementos de uma matriz são acessados por dois índices:
# + <b style="color:Blue;">i</b> – Geralmente associado às <b style="color:Blue;">linhas</b>
# + <b style="color:Green;">j</b> – Geralmente associado às <b style="color:Green;">colunas</b>
# + Acesso a elementos: < matriz > [< <b style="color:Blue;">linha</b> >] [< <b style="color:Green;">coluna</b> >]
#
# Exemplos de acesso a elementos: <br>
# + <b style="color:Red;">Mat [0] [0]</b>
# + <b style="color:Blue;">Mat [2] [2]</b>
# + <b style="color:Green;">Mat [0] [2]</b>
# + <b style="color:Yellow;">Mat [1] [0]</b>
#
# <table>
#   <tr>
#     <th><b style="color:Red;">1</b></th>
#     <th>2</th>
#     <th><b style="color:Green;">3</b></th>
#   </tr>
#   <tr>
#     <td> <b style="color:Yellow;">4</b></td>
#     <td>5</td>
#     <td>6</td>
#   </tr>
#   <tr>
#     <td>7</td>
#     <td>8</td>
#     <td><b style="color:Blue;">9</b></td>
#   </tr>
#
# </table>
#
# ```python
#
# mat = []
#
# for i in range(3):
#   linha[]
#   for j in range(3):
#     print(f"insira o elemento da linha {i} coluna {j}")
#     dado = int(input('R: '))
#     linha.append(dado)
#   mat.append(linha)
#
# for i in range(3):
#   for j in range(3):
#     print(f"O elemento da linha {i} coluna {j} é {mat[i][j]}")
#
# ```
